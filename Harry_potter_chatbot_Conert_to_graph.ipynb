# %% [markdown]
# <h1>Converting the documents to Graph data</h1>

# %% [markdown]
# ## Importing libraries

# %%
import time
import myutils
from langchain_experimental.graph_transformers.diffbot import DiffbotGraphTransformer
from langchain_experimental.graph_transformers import LLMGraphTransformer
from langchain_community.graphs import Neo4jGraph
import re

# %%
# Getting the data from jsonl file
documents=myutils.load_docs_from_jsonl('data/harry_Potter_info.jsonl')
print(len(documents))
# Out:
# 22069

# %% [markdown]
# ## Convert documents to graph data

# %%
#soruce https://python.langchain.com/v0.1/docs/integrations/graphs/diffbot/

# %%
# We are using Diffbot to convert the documents to graph, which provides nodes and relationships
diffbot_api_key = "3a512a8ce7d6db04e8e400bb4f7382da"
diffbot_nlp = DiffbotGraphTransformer(diffbot_api_key=diffbot_api_key, fact_confidence_threshold=0)

# %%
# Removing \n in documents
for document in documents:
    output_string = re.sub(r'(?<! )\n(?! )', ' ', document.page_content)
    output_string = output_string.replace('\n', ' ')
    output_string = re.sub(r'\s+', ' ', output_string).strip()
    document.page_content = output_string

# %%
# Converting the documents to Graph data, with Diffbot (NLP)
start = time.time()
graph_documents = diffbot_nlp.convert_to_graph_documents(documents[:10])
end = time.time()
print((end - start)/60)
# Out:
# 0.1638699213663737

# %%
# Graph database connection
url = "neo4j://192.168.0.102:7687"
username = "neo4j"
password = "pleaseletmein"

graph = Neo4jGraph(url=url, username=username, password=password)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\neo4j\_async_compat\network\_bolt_socket.py:528, in BoltSocket._connect(cls, resolved_address, timeout, keep_alive)
#     527 log.debug("[#0000]  C: <OPEN> %s", resolved_address)
# --> 528 s.connect(resolved_address)
#     529 s.settimeout(t)
#
# TimeoutError: [WinError 10060] Et forsøg på at oprette forbindelse mislykkedes, fordi den part, der havde oprettet forbindelse, ikke svarede korrekt efter en periode, eller en oprettet forbindelse blev afbrudt, fordi værten ikke svarede
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 6>()
#       3 username = "neo4j"
# ...

# %%
# Add the converted data to the graph database
graph.add_graph_documents(graph_documents)

# %%
print(graph_documents[0])
# Out:
# nodes=[] relationships=[] source=Document(page_content='Harry Potter and the Philosopher\'s Stone | Harry Potter Wiki | Fandom Harry Potter Wiki Explore Main Page Discuss All Pages Community Interactive Maps Recent Blog Posts Books The Seven Novels Harry Potter and the Philosopher\'s Stone Harry Potter and the Chamber of Secrets Harry Potter and the Prisoner of Azkaban Harry Potter and the Goblet of Fire Harry Potter and the Order of the Phoenix Harry Potter and the Half-Blood Prince Harry Potter and the Deathly Hallows Rowling\'s Companion Writings Fantastic Beasts and Where to Find Them Quidditch Through the Ages The Tales of Beedle the Bard Harry Potter Prequel Pottermore Other Written Works Harry Potter: A Pop-Up Book Harry Potter Film Wizardry Harry Potter Page to Screen: The Complete Filmmaking Journey LEGO Harry Potter: Building the Magical World LEGO Harry Potter: Characters of the Magical World Characters Harry Potter Hermione Granger Ronald Weasley Ginny Weasley Albus Dumbl
# ...
